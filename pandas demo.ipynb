# %%
import pandas as pd

# %%
na_vals = ["Na","Missing"]
df = pd.read_csv('results.csv',index_col="Respondent")

# %%
schema = pd.read_csv("survey_results_schema.csv",index_col="Column")

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
pd.set_option('display.max_columns',85)

# %%
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
schema.loc()

# %%
filt = df['LanguageWorkedWith'].str.contains('Python',na=False)

# %%
 df.loc[filt, "LanguageWorkedWith"].str.replace("Python", "React")
# Out:
# Respondent
# 1                           HTML/CSS;Java;JavaScript;React
# 2                                       C++;HTML/CSS;React
# 4                                       C;C++;C#;React;SQL
# 5               C++;HTML/CSS;Java;JavaScript;React;SQL;VBA
# 8        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 84539    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 85738       Bash/Shell/PowerShell;C++;React;Ruby;Other(s):
# 86566       Bash/Shell/PowerShell;HTML/CSS;React;Other(s):
# 87739              C;C++;HTML/CSS;JavaScript;PHP;React;SQL
# 88212                            HTML/CSS;JavaScript;React
# Name: LanguageWorkedWith, Length: 36443, dtype: str

# %%
df["LanguageWorkedWith"]
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 3                                                 HTML/CSS
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#                                ...
# 88377                        HTML/CSS;JavaScript;Other(s):
# 88601                                                  NaN
# 88802                                                  NaN
# 88816                                                  NaN
# 88863    Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# Name: LanguageWorkedWith, Length: 88883, dtype: str

# %%
df.rename(columns={"ConvertedComp": "Salary"},inplace=True)

# %%
df['Salary']
# Out:
# Respondent
# 1            NaN
# 2            NaN
# 3         8820.0
# 4        61000.0
# 5            NaN
#           ...
# 88377        NaN
# 88601        NaN
# 88802        NaN
# 88816        NaN
# 88863        NaN
# Name: Salary, Length: 88883, dtype: float64

# %%
df["Hobbyist"].map({"Yes":True,"No":False})
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4        False
# 5         True
#          ...
# 88377     True
# 88601    False
# 88802    False
# 88816    False
# 88863     True
# Name: Hobbyist, Length: 88883, dtype: bool

# %%
df["Main"] = df["Student"]+" "+df["Hobbyist"]

# %%
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df.drop(columns=["Main"])
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df["Salary"].nlargest(10)
# Out:
# Respondent
# 58      2000000.0
# 102     2000000.0
# 166     2000000.0
# 436     2000000.0
# 452     2000000.0
# 491     2000000.0
# 539     2000000.0
# 770     2000000.0
# 789     2000000.0
# 1232    2000000.0
# Name: Salary, dtype: float64

# %%
df.median(numeric_only=True)
# Out:
# CompTotal      62000.0
# Salary         57287.0
# WorkWeekHrs       40.0
# CodeRevHrs         4.0
# Age               29.0
# dtype: float64

# %%
df.describe()
# Out:
#           CompTotal        Salary   WorkWeekHrs    CodeRevHrs           Age
# count  5.594500e+04  5.582300e+04  64503.000000  49790.000000  79210.000000
# mean   5.519014e+11  1.271107e+05     42.127197      5.084308     30.336699
# std    7.331926e+13  2.841523e+05     37.287610      5.513931      9.178390
# min    0.000000e+00  0.000000e+00      1.000000      0.000000      1.000000
# 25%    2.000000e+04  2.577750e+04     40.000000      2.000000     24.000000
# 50%    6.200000e+04  5.728700e+04     40.000000      4.000000     29.000000
# 75%    1.200000e+05  1.000000e+05     44.750000      6.000000     35.000000
# max    1.000000e+16  2.000000e+06   4850.000000     99.000000     99.000000

# %%
df["SocialMedia"].value_counts(normalize=True)
# Out:
# SocialMedia
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: proportion, dtype: float64

# %%
df["Country"].value_counts()
# Out:
# Country
# United States                       20949
# India                                9061
# Germany                              5866
# United Kingdom                       5737
# Canada                               3395
#                                     ...
# Papua New Guinea                        1
# Saint Kitts and Nevis                   1
# Saint Vincent and the Grenadines        1
# Sao Tome and Principe                   1
# Chad                                    1
# Name: count, Length: 179, dtype: int64

# %%
df['Country'] = df['Country'].str.strip()

# %%
country_grp = df.groupby("Country")  # No brackets
country_grp.get_group("Ukraine")
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 5                              I am a developer by profession      Yes
# 7                              I am a developer by profession       No
# 329                            I am a developer by profession      Yes
# 371                            I am a developer by profession       No
# 521                            I am a developer by profession      Yes
# ...                                                       ...      ...
# 88772       I am not primarily a developer, but I write co...      Yes
# 88773                          I am a developer by profession      Yes
# 88792                          I am a developer by profession      Yes
# 19758                                                     NaN      Yes
# 69366                                                     NaN       No
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
country_grp["Salary"].median().loc["Germany"]
# Out:
# np.float64(63016.0)

# %%
country_grp["LanguageWorkedWith"].apply(lambda x: x.str.contains("Python").sum())
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
country_py = country_grp["LanguageWorkedWith"].apply(lambda x: x.str.contains("Python").sum())
country_py
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
country = df["Country"].value_counts()
country
# Out:
# Country
# United States                       20949
# India                                9061
# Germany                              5866
# United Kingdom                       5737
# Canada                               3395
#                                     ...
# Papua New Guinea                        1
# Saint Kitts and Nevis                   1
# Saint Vincent and the Grenadines        1
# Sao Tome and Principe                   1
# Chad                                    1
# Name: count, Length: 179, dtype: int64

# %%
example = pd.concat([country,country_py],axis='columns',sort=False)
example
# Out:
#                                   count  LanguageWorkedWith
# Country
# United States                     20949               10083
# India                              9061                3105
# Germany                            5866                2451
# United Kingdom                     5737                2384
# Canada                             3395                1558
# ...                                 ...                 ...
# Papua New Guinea                      1                   0
# Saint Kitts and Nevis                 1                   0
# Saint Vincent and the Grenadines      1                   0
# Sao Tome and Principe                 1                   1
# Chad                                  1                   0
#
# [179 rows x 2 columns]

# %%
example.rename(columns={"LanguageWorkedWith":"lang"},inplace=True)
example
# Out:
#                                   count   lang
# Country
# United States                     20949  10083
# India                              9061   3105
# Germany                            5866   2451
# United Kingdom                     5737   2384
# Canada                             3395   1558
# ...                                 ...    ...
# Papua New Guinea                      1      0
# Saint Kitts and Nevis                 1      0
# Saint Vincent and the Grenadines      1      0
# Sao Tome and Principe                 1      1
# Chad                                  1      0
#
# [179 rows x 2 columns]

# %%
# 1. Get total respondents per country
country_respondents = country_grp["Country"].value_counts()

# 2. Combine them into a single DataFrame
country_py_df = pd.concat([country_respondents, country_py], axis=1)

# 3. Rename the columns so they match your formula
country_py_df.rename(columns={"count": "NumRespondents", "LanguageWorkedWith": "NumKnowsPython"}, inplace=True)
country_py_df.loc["Japan"]
# Out:
# NumRespondents    391
# NumKnowsPython    182
# Name: Japan, dtype: int64

# %%
df.dropna()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 20          I am not primarily a developer, but I write co...       No
# 39                             I am a developer by profession      Yes
# 44                             I am a developer by profession      Yes
# 83                             I am a developer by profession      Yes
# 104                            I am a developer by profession      Yes
# ...                                                       ...      ...
# 88711                          I am a developer by profession       No
# 88728                          I am a developer by profession      Yes
# 88786                          I am a developer by profession      Yes
# 88853                          I am a developer by profession      Yes
# 88878                          I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df.isna()
# Out:
#             MainBranch  Hobbyist  OpenSourcer  OpenSource  Employment  \
# Respondent
# 1                False     False        False       False       False
# 2                False     False        False       False       False
# 3                False     False        False       False       False
# 4                False     False        False       False       False
# 5                False     False        False       False       False
# ...                ...       ...          ...         ...         ...
# 88377             True     False        False       False       False
# 88601             True     False        False       False        True
# 88802             True     False        False        True       False
# 88816             True     False        False       False       False
# 88863             True     False        False       False       False
#
#             Country  Student  EdLevel  UndergradMajor  EduOther  OrgSize  \
# Respondent
# ...

# %%
df["YearsCode"].unique()
# Out:
# <StringArray>
# [                 '4',                  nan,                  '3',
#                  '16',                 '13',                  '6',
#                   '8',                 '12',                  '2',
#                   '5',                 '17',                 '10',
#                  '14',                 '35',                  '7',
#    'Less than 1 year',                 '30',                  '9',
#                  '26',                 '40',                 '19',
#                  '15',                 '20',                 '28',
#                  '25',                  '1',                 '22',
#                  '11',                 '33',                 '50',
#                  '41',                 '18',                 '34',
#                  '24',                 '23',                 '42',
#                  '27',                 '21',                 '36',
#                  '32',                 '39',                 '38',
# ...

# %%
df["YearsCode"].replace('Less than 1 year',0)
# Out:
# Respondent
# 1          4
# 2        NaN
# 3          3
# 4          3
# 5         16
#         ...
# 88377    NaN
# 88601    NaN
# 88802    NaN
# 88816    NaN
# 88863      8
# Name: YearsCode, Length: 88883, dtype: object

# %%
df["YearsCode"].replace('More than 50 years',51)
# Out:
# Respondent
# 1          4
# 2        NaN
# 3          3
# 4          3
# 5         16
#         ...
# 88377    NaN
# 88601    NaN
# 88802    NaN
# 88816    NaN
# 88863      8
# Name: YearsCode, Length: 88883, dtype: object

# %%
df["YearsCode"] =  df["YearsCode"].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df["YearsCode"] =  df["YearsCode"].astype(float)
#
# File ~\corey-schafer-learning\.venv\Lib\site-packages\pandas\core\generic.py:6541, in NDFrame.astype(self, dtype, copy, errors)
#    6537             results = [ser.astype(dtype, errors=errors) for _, ser in self.items()]
#    6538
#    6539         else:
#    6540             # else, only a single dtype is given
# -> 6541             new_data = self._mgr.astype(dtype=dtype, errors=errors)
#    6542             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6543             return res.__finalize__(self, method="astype")
#    6544
#
# File ~\corey-schafer-learning\.venv\Lib\site-packages\pandas\core\internals\managers.py:614, in BaseBlockManager.astype(self, dtype, errors)
# ...

# %%
filter = (df["Country"]== 'India')
india_df = df.loc[filt]
india_df.head()
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 2           I am a student who is learning to code       No
# 4                   I am a developer by profession       No
# 5                   I am a developer by profession      Yes
# 8                      I code primarily as a hobby      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 4                                Never
# 5           Once a month or more often
# 8              Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 4           The quality of OSS and closed source software ...
# 5           OSS is, on average, of HIGHER quality than pro...
# ...

# %%
india_df.to_csv("modified.csv")

# %%
india_df.to_csv("modified.tsv",sep='\t')
india_df
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 2           I am a student who is learning to code       No
# 4                   I am a developer by profession       No
# 5                   I am a developer by profession      Yes
# 8                      I code primarily as a hobby      Yes
# ...                                            ...      ...
# 84539                                          NaN      Yes
# 85738                                          NaN      Yes
# 86566                                          NaN      Yes
# 87739                                          NaN      Yes
# 88212                                          NaN       No
#
#                                                   OpenSourcer  \
# Respondent
# 1                                                       Never
# 2                                     Less than once per year
# ...

# %%
india_df.to_excel("modified.xlsx")

# %%
read = pd.read_excel("modified.xlsx",index_col="Respondent")
read
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 2           I am a student who is learning to code       No
# 4                   I am a developer by profession       No
# 5                   I am a developer by profession      Yes
# 8                      I code primarily as a hobby      Yes
# ...                                            ...      ...
# 84539                                          NaN      Yes
# 85738                                          NaN      Yes
# 86566                                          NaN      Yes
# 87739                                          NaN      Yes
# 88212                                          NaN       No
#
#                                                   OpenSourcer  \
# Respondent
# 1                                                       Never
# 2                                     Less than once per year
# ...

# %%
from sqlalchemy import create_engine
import psycopg2

# %%
engine = create_engine("postgresql://dbuser:dbpass@localhost:8888/sample_db")

# %%
india_df.to_sql('sample_table',engine,if_exists='replace')

# %%
sql = pd.read_sql('sample_table',engine,index_col='Respondent')
